# %% [markdown]
# # Cone Detection

# %% [markdown]
# ### Download the YOLOv5 project:

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17067, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 17067 (delta 24), reused 28 (delta 12), pack-reused 17022 (from 1)
# Receiving objects: 100% (17067/17067), 15.68 MiB | 9.43 MiB/s, done.
# Resolving deltas: 100% (11714/11714), done.

# %%
# %cd yolov5
# Out:
# /home/idansa/Desktop/idan/bgracing/yolov5

# %% [markdown]
# ### Download the data set from roboflow

# %% [markdown]
# The data is alredy seperated into train test and validation. <br>
# It contains 1954 images. <br>
# The train set is 70% of the data, the test set is 20% and the validation set is 10% of the data.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="<API KEY>")
project = rf.workspace("mms-ceu49").project("cone_detection-q6gnx")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# /usr/bin/pip:6: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import load_entry_point
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to cone_detection-1 in yolov5pytorch:: 100%|██████████████████████████████| 3920/3920 [00:00<00:00, 15764.11it/s]

# %% [markdown]
# ### Train the model

# %% [markdown]
# Batch size is 16 images. <br>
# Epochs (number of train runs) is 3

# %%
# !python3 train.py \
  --img 640 \
  --batch 16 \
  --epochs 3 \
  --data cone_detection-1/data.yaml \
  --weights yolov5s.pt \
  --name yolov5s_results  \
  --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=cone_detection-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-388-g882c35fc Python-3.8.10 torch-2.2.1+cu121 CPU
#
# ...

# %% [markdown]
# #### Note: because of technical issues, only 1 epoch finished running before fail. (running on cpu).

# %% [markdown]
# ## Running the trained model on the sample mp4 file

# %% [markdown]
# The confidence level is 0.5. chosen after multiple tries of confidence levels, this seemed to be the best accuracy level for the model on the sample video.

# %%
# !python3 detect.py \
--weights runs/train/yolov5s_results2/weights/best.pt \
--conf 0.5 \
--source ../fsd1.mp4
# Out:
# detect: weights=['runs/train/yolov5s_results2/weights/best.pt'], source=../fsd1.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-388-g882c35fc Python-3.8.10 torch-2.2.1+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/819) /home/idansa/Desktop/idan/bgracing/fsd1.mp4: 384x640 1 blue_cone, 1 yellow_cone, 37.6ms
# video 1/1 (2/819) /home/idansa/Desktop/idan/bgracing/fsd1.mp4: 384x640 4 blue_cones, 2 yellow_cones, 36.6ms
# ...

# %% [markdown]
# ## How I would continue:

# %% [markdown]
# 1. Use a machine with cuda installed.
# 2. Retrain the model with more epochs and chose the best output of those epochs.
# 3. Use a larger data set containing more varied images.
